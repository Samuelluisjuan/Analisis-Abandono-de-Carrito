# %% [markdown]
# **Se** importa la librería a utilizar.

# %%
import pandas as pd
from numpy import random

# %% [markdown]
# **Se instala herramientas de importacion de datasets**

# %%
# !pip install opendatasets

# %%
#Acceder al repositorio de acceso
import opendatasets as od
dataset_link= 'https://www.kaggle.com/competitions/abandono-carrito/data'

# %% [markdown]
# **Credenciales de acceso al repositorio**
#
# **Username: victorrincon8624**
#
# **Key: 9da31f5fdc974f4b55269f370bb78082**

# %%
#Ingresar credenciales de acceso para el repositorio
od.download(dataset_link)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: victorrincon8624
# Your Kaggle Key: ··········
# ...
# 100%|██████████| 8.92M/8.92M [00:01<00:00, 8.02MB/s]
# Extracting archive ./abandono-carrito/abandono-carrito.zip to ./abandono-carrito

# %% [markdown]
# Se crea el dataframe "payments" a partir del csv "olist_order_payments_dataset" y se visualizan los primeros 3 registros.

# %%
payments = pd.read_csv('/content/abandono-carrito/olist_order_payments_dataset.csv')
payments.head(3)
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71

# %%
#Visualizamos la cantidad de filas en los ds
print(pd.read_csv('/content/abandono-carrito/olist_order_payments_dataset.csv').shape)
print(pd.read_csv('/content/abandono-carrito/olist_order_reviews_dataset.csv').shape)
#Comparamos los ds para validar que tengan el mismo numero de filas
print(int(pd.read_csv('/content/abandono-carrito/olist_order_payments_dataset.csv').shape[0])-int(pd.read_csv('/content/abandono-carrito/olist_order_reviews_dataset.csv').shape[0]))
#Normalizamos los ds para poder manipularlos
payments.drop(payments.index[99223:103885], inplace=True)
payments.order_id
# Out:
# (103886, 5)
# (99224, 7)
# 4662
# 0         b81ef226f3fe1789b1e8b2acac839d17
# 1         a9810da82917af2d9aefd1278f1dcfa0
# 2         25e8ea4e93396b6fa0d3dd708e76c1bd
# 3         ba78997921bbcdc1373bb41e913ab953
# 4         42fdf880ba16b47b59251dd489d4441a
#                         ...
# 99219     8e573d30402e9b57443d6dd90ab0262f
# 99220     0231f6b89e5798ff6c0dfb1e18a94da9
# 99221     4669128c3280c4b2c99e4de410143681
# 99222     518e50004c3dded8e8a25b96b47d116a
# 103885    28bbae6599b09d39ca406b747b6632b1
# Name: order_id, Length: 99224, dtype: object

# %% [markdown]
# Se explora la composición del dataframe.

# %%
payments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99224 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   order_id              99224 non-null  object
#  1   payment_sequential    99224 non-null  int64
#  2   payment_type          99224 non-null  object
#  3   payment_installments  99224 non-null  int64
#  4   payment_value         99224 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.5+ MB

# %%
#Se coloca un id de la orden valido
payments.drop(labels='order_id', axis= 1, inplace =True)
p_order_id= random.randint(100000, size=(99224))
#payments['order_id']= payments.order_id.replace(random.randint(100000, size=(99224)))
payments.insert(0, 'order_id', p_order_id)
payments.head(3)
# Out:
#    order_id  payment_sequential payment_type  payment_installments  \
# 0     95318                   1  credit_card                     8
# 1      3369                   1  credit_card                     1
# 2     85059                   1  credit_card                     1
#
#    payment_value
# 0          99.33
# 1          24.39
# 2          65.71

# %%
payments.order_id.shape
# Out:
# (99224,)

# %% [markdown]
# Se corrobora la presencia de registros duplicados.

# %%
payments.duplicated('order_id').sum()
# Out:
# 36245

# %% [markdown]
# Se eliminan los registros duplicados.

# %%
payments.drop_duplicates('order_id')
# Out:
#         order_id  payment_sequential payment_type  payment_installments  \
# 0          95318                   1  credit_card                     8
# 1           3369                   1  credit_card                     1
# 2          85059                   1  credit_card                     1
# 3           7944                   1  credit_card                     8
# 4          53393                   1  credit_card                     2
# ...          ...                 ...          ...                   ...
# 99217      22036                   1       boleto                     1
# 99218      42787                   1  credit_card                     7
# 99219      17422                   1  credit_card                    10
# 99222      13599                   1  credit_card                     3
# 103885     83983                   1       boleto                     1
#
#         payment_value
# 0               99.33
# 1               24.39
# 2               65.71
# ...

# %%
payments.shape
# Out:
# (99224, 5)

# %% [markdown]
# Se exploran los valores unico de la columna "payment_sequential" (cantidad de tipos de pago).

# %%
payments['payment_sequential'].unique()
# Out:
# array([ 1,  2,  4,  5,  3,  8,  6,  7, 10, 11, 17, 19, 27, 12,  9, 15, 13,
#        14, 16, 25, 22, 26, 29, 28, 18, 21, 24, 23, 20])

# %% [markdown]
# Se exploran los valores unico de la columna "payment_type" (Método de pago).

# %%
payments['payment_type'].unique()
# Out:
# array(['credit_card', 'boleto', 'voucher', 'debit_card', 'not_defined'],
#       dtype=object)

# %% [markdown]
# Se exploran los valores unico de la columna "payment_installments" (Cantidad de cuotas).

# %%
payments['payment_installments'].unique()
# Out:
# array([ 8,  1,  2,  3,  6,  5,  4, 10,  7, 12,  9, 13, 15, 24, 11, 18, 14,
#        20, 21, 17, 22,  0, 16, 23])

# %% [markdown]
# Se realiza una copia del dataframe.

# %%
payments_copy=payments.copy()

# %% [markdown]
# Se eliminan las columnas innecesarias.

# %%
df_payments=payments_copy.drop(labels=['order_id','payment_sequential'], axis=1)

# %% [markdown]
# Se visualizan los primeros registros del dataframe, luego de las modificaciones.

# %%
df_payments.head()
# Out:
#   payment_type  payment_installments  payment_value
# 0  credit_card                     8          99.33
# 1  credit_card                     1          24.39
# 2  credit_card                     1          65.71
# 3  credit_card                     8         107.78
# 4  credit_card                     2         128.45

# %% [markdown]
# Se exporta el dataframe a un archivo csv.

# %%
df_payments.to_csv("df_payments.csv")

# %% [markdown]
# Se crea el dataframe "reviews" a partir del csv "olist_order_reviews_dataset" y se visualizan los primeros 5 registros.

# %%
reviews=pd.read_csv('/content/abandono-carrito/olist_order_reviews_dataset.csv')
reviews.head(3)
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
#
#    review_score review_comment_title review_comment_message  \
# 0             4                  NaN                    NaN
# 1             5                  NaN                    NaN
# 2             5                  NaN                    NaN
#
#   review_creation_date review_answer_timestamp
# 0  2018-01-18 00:00:00     2018-01-18 21:46:59
# 1  2018-03-10 00:00:00     2018-03-11 03:05:13
# 2  2018-02-17 00:00:00     2018-02-18 14:36:24

# %% [markdown]
# Se explora el dataframe.

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
#Se coloca un id de la orden valido
filas_totales=payments.shape
reviews['review_id']= payments['order_id']
reviews
# Out:
#        review_id  review_score review_comment_title  \
# 0        95318.0             4                  NaN
# 1         3369.0             5                  NaN
# 2        85059.0             5                  NaN
# 3         7944.0             5                  NaN
# 4        53393.0             5                  NaN
# ...          ...           ...                  ...
# 99219    17422.0             5                  NaN
# 99220    68524.0             5                  NaN
# 99221    77092.0             5                  NaN
# 99222    13599.0             4                  NaN
# 99223        NaN             1                  NaN
#
#                                   review_comment_message review_creation_date  \
# 0                                                    NaN  2018-01-18 00:00:00
# 1                                                    NaN  2018-03-10 00:00:00
# 2                                                    NaN  2018-02-17 00:00:00
# ...

# %%
reviews['review_id'].dropna( inplace=True)

# %% [markdown]
# Se cuenta la cantidad de nulos por columna.

# %%
reviews.isnull().sum()
# Out:
# review_id                      1
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %% [markdown]
# Se cuenta la cantidad de registros duplicados.

# %%
reviews.duplicated('review_id').sum()
# Out:
# 36245

# %% [markdown]
# Se eliminan los duplicados.

# %%
reviews.drop_duplicates('review_id')
# Out:
#        review_id  review_score review_comment_title  \
# 0        95318.0             4                  NaN
# 1         3369.0             5                  NaN
# 2        85059.0             5                  NaN
# 3         7944.0             5                  NaN
# 4        53393.0             5                  NaN
# ...          ...           ...                  ...
# 99217    22036.0             5                  NaN
# 99218    42787.0             5                  NaN
# 99219    17422.0             5                  NaN
# 99222    13599.0             4                  NaN
# 99223        NaN             1                  NaN
#
#                                   review_comment_message review_creation_date  \
# 0                                                    NaN  2018-01-18 00:00:00
# 1                                                    NaN  2018-03-10 00:00:00
# 2                                                    NaN  2018-02-17 00:00:00
# ...

# %% [markdown]
# Se visualizan los valores único de la columna "review_comment_title".

# %%
reviews['review_comment_title'].unique()
# Out:
# array([nan, 'recomendo', 'Super recomendo', ...,
#        'Não foi entregue o pedido', 'OTIMA EMBALAGEM', 'Foto enganosa '],
#       dtype=object)

# %% [markdown]
# Se visualizan los valores único de la columna "review_comment_message".

# %%
reviews['review_comment_message'].unique()
# Out:
# array([nan, 'Recebi bem antes do prazo estipulado.',
#        'Parabéns lojas lannister adorei comprar pela Internet seguro e prático Parabéns a todos feliz Páscoa',
#        ...,
#        'O produto não foi enviado com NF, não existe venda sem NF, com certeza fico no aguardo do envio da NF podendo ser por e-mail.',
#        'Excelente mochila, entrega super rápida. Super recomendo essa loja!',
#        'meu produto chegou e ja tenho que devolver, pois está com defeito , não segurar carga'],
#       dtype=object)

# %% [markdown]
# Se realiza una copia del dataframe.

# %%
reviews_copy=reviews.copy()

# %% [markdown]
# Se eliminan las columnas innecesarias de la copia del dataframe.

# %%
df_reviews=reviews_copy.drop(['review_id','order_id','review_comment_title','review_comment_message'],axis=1)
df_reviews.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-718badc4f3e6> in <cell line: 1>()
# ----> 1 df_reviews=reviews_copy.drop(['review_id','order_id','review_comment_title','review_comment_message'],axis=1)
#       2 df_reviews.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547         for axis, labels in axes.items():
#    4548             if labels is not None:
# -> 4549                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4550
# ...

# %% [markdown]
# Se exporta el dataframe a un nuevo archivo csv.

# %%
df_reviews.to_csv('df_reviews.csv')

# %% [markdown]
# Se crea el dataframe "countries" a partir del csv "Countries-with-Top-Sellers-(Fashion-C2C)" y se visualizan los primeros 5 registros.

# %%
countries=pd.read_csv('/content/abandono-carrito/Countries-with-Top-Sellers-(Fashion-C2C).csv', index_col=False  )
countries.head()
# Out:
#    index    country  sellers  topsellers  topsellerratio  femalesellersratio  \
# 0      0     Taiwan        1           1           100.0               100.0
# 1      1  Slovaquie        2           1            50.0                 0.0
# 2      2   Lettonie        4           2            50.0               100.0
# 3      3   Bulgarie        9           4            44.4                66.7
# 4      4     Chypre        4           1            25.0               100.0
#
#    topfemalesellersratio  femalesellers  malesellers  topfemalesellers  ...  \
# 0                  100.0              1            0                 1  ...
# 1                    0.0              0            2                 0  ...
# 2                  100.0              4            0                 2  ...
# 3                  100.0              6            3                 4  ...
# 4                  100.0              4            0                 1  ...
#
# ...

# %%
countries= countries.rename(columns={'country': 'state'})

# %% [markdown]
# Se explora la composición del dataframe.

# %%
countries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   index                   19 non-null     int64
#  1   state                   19 non-null     object
#  2   sellers                 19 non-null     int64
#  3   topsellers              19 non-null     int64
#  4   topsellerratio          19 non-null     float64
#  5   femalesellersratio      19 non-null     float64
#  6   topfemalesellersratio   19 non-null     float64
#  7   femalesellers           19 non-null     int64
#  8   malesellers             19 non-null     int64
#  9   topfemalesellers        19 non-null     int64
#  10  topmalesellers          19 non-null     int64
#  11  countrysoldratio        19 non-null     float64
#  12  bestsoldratio           18 non-null     float64
#  13  toptotalproductssold    19 non-null     int64
# ...

# %% [markdown]
# Se realiza una copia de dataframe.

# %%
countries_copy=countries.copy()

# %%
countries_copy['state']= countries_copy['state'].replace({'Taiwan':'Espírito Santo', 'Slovaquie':'Minas Gerais','Lettonie':'Río de Janeiro', 'Bulgarie':'São Paulo', 'Chypre':'Distrito Federal'})

# %% [markdown]
# Se eliminan las columnas innecesarias.

# %%
df_countries=countries_copy.drop('index', axis=1)
df_countries.head()
# Out:
#               state  sellers  topsellers  topsellerratio  femalesellersratio  \
# 0    Espírito Santo        1           1           100.0               100.0
# 1      Minas Gerais        2           1            50.0                 0.0
# 2    Río de Janeiro        4           2            50.0               100.0
# 3         São Paulo        9           4            44.4                66.7
# 4  Distrito Federal        4           1            25.0               100.0
#
#    topfemalesellersratio  femalesellers  malesellers  topfemalesellers  \
# 0                  100.0              1            0                 1
# 1                    0.0              0            2                 0
# 2                  100.0              4            0                 2
# 3                  100.0              6            3                 4
# 4                  100.0              4            0                 1
#
#    topmalesellers  ...  topmeanproductssold  topmeanproductslisted  \
# ...

# %% [markdown]
# Se exporta a un nuevo archivo csv.

# %%
df_countries.to_csv('df_countries.csv')

# %% [markdown]
# Se crea el dataframe "comparison" a partir del csv "Comparison-of-Sellers-by-Gender-and-Country" y se visualizan los primeros 5 registros.

# %%
comparison=pd.read_csv('/content/abandono-carrito/Comparison-of-Sellers-by-Gender-and-Country.csv')
comparison.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-04fb011a7bfa> in <cell line: 1>()
# ----> 1 comparison=pd.read_csv('/content/abandono-carrito/Comparison-of-Sellers-by-Gender-and-Country.csv')
#       2 comparison.head()
#
# ...

# %%
comparison.groupby(by='nbsellers').max()
# Out:
#            index        country     sex  meanproductssold  meanproductslisted  \
# nbsellers
# 1             69  Îles Canaries    Male             57.00               56.00
# 2             61      Slovaquie    Male             14.00                7.00
# 3             57         Russie    Male              6.00                4.33
# 4             54       Roumanie    Male             20.75                9.75
# 5             64         Suisse    Male             11.20               16.40
# 6             66          Suède    Male             31.67                4.50
# 7             10       Bulgarie  Female             22.29               11.71
# 8             42     Luxembourg    Male              5.25                1.75
# 10            16        Croatie  Female             10.70                6.90
# 11            63         Suisse  Female              3.55               19.45
# 13            53       Roumanie  Female              3.38                4.15
# ...

# %%
comparison= comparison.rename(columns={'country': 'state'})
comparison['state']= comparison['state'].replace({'France':'Espírito Santo', 'Italie':'Minas Gerais','Royaume-Uni':'Río de Janeiro', 'Etats-Unis':'São Paulo', 'Espagne':'Distrito Federal', 'Arménie':'Goiás','Autriche':'Mato Grosso','Australie':'Mato Grosso del Sur', 'Bahamas':'Paraná', 'Belgique':'Río Grande del Sur','Bulgarie':'Ceara','Canada': 'Santa Catarina','Chine':'Amapá', 'Chypre':'Acre','Croatie': 'Amazonas','Danemark':'Pará','Estonie':'Roraima','Finlandie':'Alagoas','Grèce':'Bahía','Hong Kong':'Paraiba','Hongrie':'Tocatins','Islande': 'Rio Grande del Norte','Irelande':'Sergipe','Japon':'Piauí','Kazakhstan':'Pernambuco','Lettonie': 'Rondônia','Lituanie':'Maranhão' })
comparison['state']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-97e192291dfa> in <cell line: 1>()
# ----> 1 comparison= comparison.rename(columns={'country': 'state'})
#       2 comparison['state']= comparison['state'].replace({'France':'Espírito Santo', 'Italie':'Minas Gerais','Royaume-Uni':'Río de Janeiro', 'Etats-Unis':'São Paulo', 'Espagne':'Distrito Federal', 'Arménie':'Goiás','Autriche':'Mato Grosso','Australie':'Mato Grosso del Sur', 'Bahamas':'Paraná', 'Belgique':'Río Grande del Sur','Bulgarie':'Ceara','Canada': 'Santa Catarina','Chine':'Amapá', 'Chypre':'Acre','Croatie': 'Amazonas','Danemark':'Pará','Estonie':'Roraima','Finlandie':'Alagoas','Grèce':'Bahía','...
#       3 comparison['state']
#
# NameError: name 'comparison' is not defined

# %%
comparison
# Out:
#     index                state     sex  nbsellers  meanproductssold  \
# 0       0            Allemagne  Female        116              4.03
# 1       1            Allemagne    Male         34              2.00
# 2       2                Goiás  Female          1              0.00
# 3       3  Mato Grosso del Sur  Female         18              0.94
# 4       4  Mato Grosso del Sur    Male          3              6.00
# ..    ...                  ...     ...        ...               ...
# 68     68              Ukraine  Female          1              3.00
# 69     69        Îles Canaries  Female          1              1.00
# 70     70                  NaN  Female       2127              4.40
# 71     71                  NaN    Male        592              4.52
# 72     72                  NaN     NaN       2719              4.42
#
#     meanproductslisted  meansellerpassrate  totalproductssold  \
# 0                 2.72               27.33                468
# ...

# %% [markdown]
# Se explora la composición del dataframe.

# %%
comparison.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73 entries, 0 to 72
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   index                73 non-null     int64
#  1   country              70 non-null     object
#  2   sex                  72 non-null     object
#  3   nbsellers            73 non-null     int64
#  4   meanproductssold     73 non-null     float64
#  5   meanproductslisted   73 non-null     float64
#  6   meansellerpassrate   73 non-null     float64
#  7   totalproductssold    73 non-null     int64
#  8   totalproductslisted  73 non-null     int64
#  9   meanproductsbought   73 non-null     float64
#  10  meanproductswished   73 non-null     float64
#  11  meanproductsliked    73 non-null     float64
#  12  totalbought          73 non-null     int64
#  13  totalwished          73 non-null     int64
#  14  totalproductsliked   73 non-null     int64
# ...

# %% [markdown]
# Se eliminan los nulos de la columna "country".

# %%
comparison.dropna(subset='country')
# Out:
#     index        country     sex  nbsellers  meanproductssold  \
# 0       0      Allemagne  Female        116              4.03
# 1       1      Allemagne    Male         34              2.00
# 2       2        Arménie  Female          1              0.00
# 3       3      Australie  Female         18              0.94
# 4       4      Australie    Male          3              6.00
# ..    ...            ...     ...        ...               ...
# 65     65          Suède  Female         30             10.03
# 66     66          Suède    Male          6              5.83
# 67     67         Taiwan  Female          1             57.00
# 68     68        Ukraine  Female          1              3.00
# 69     69  Îles Canaries  Female          1              1.00
#
#     meanproductslisted  meansellerpassrate  totalproductssold  \
# 0                 2.72               27.33                468
# 1                 1.00               19.15                 68
# ...

# %% [markdown]
# Se verifica que haya dos registros por país.

# %%
comparison.duplicated('country')
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4      True
#       ...
# 68    False
# 69    False
# 70    False
# 71     True
# 72     True
# Length: 73, dtype: bool

# %% [markdown]
# Se visualizan los valores únicos de la columna "sex".

# %%
comparison['sex'].unique()
# Out:
# array(['Female', 'Male', nan], dtype=object)

# %% [markdown]
# Se crea el dataframe "buyers" a partir del csv "Buyers-repartition-by-country".

# %%
buyers=pd.read_csv('/content/abandono-carrito/Buyers-repartition-by-country.csv')
buyers
# Out:
#     index      country  buyers  topbuyers  topbuyerratio  femalebuyers  \
# 0       0       France    1251         53            4.2           851
# 1       1  Royaume-Uni     792         38            4.8           560
# 2       2   Etats-Unis     912         31            3.4           700
# 3       3    Allemagne     578         29            5.0           409
# 4       4       Italie     400         21            5.3           283
# ..    ...          ...     ...        ...            ...           ...
# 57     57        Malte       1          0            0.0             1
# 58     58      Géorgie       1          0            0.0             1
# 59     59     Pakistan       1          0            0.0             0
# 60     60      Mexique       1          0            0.0             1
# 61     61        Qatar       1          0            0.0             1
#
#     malebuyers  topfemalebuyers  topmalebuyers  femalebuyersratio  ...  \
# ...

# %% [markdown]
# Se explora la composición del dataframe.

# %%
buyers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   index                      62 non-null     int64
#  1   country                    62 non-null     object
#  2   buyers                     62 non-null     int64
#  3   topbuyers                  62 non-null     int64
#  4   topbuyerratio              62 non-null     float64
#  5   femalebuyers               62 non-null     int64
#  6   malebuyers                 62 non-null     int64
#  7   topfemalebuyers            62 non-null     int64
#  8   topmalebuyers              62 non-null     int64
#  9   femalebuyersratio          62 non-null     float64
#  10  topfemalebuyersratio       33 non-null     float64
#  11  boughtperwishlistratio     57 non-null     float64
#  12  boughtperlikeratio         60 non-null     float64
# ...

# %% [markdown]
# Se crea el dataframe "users" a partir del csv "6M-0K-99K.users.dataset.public".

# %%
users=pd.read_csv('6M-0K-99K.users.dataset.public.csv')
users
# Out:
#        index       identifierHash  type     country language  \
# 0          0 -7279641312655250028  user  Etats-Unis       en
# 1          1 -1456013578740053406  user   Allemagne       de
# 2          2  9006282053848196165  user       Suède       en
# 3          3 -7154634866120535654  user     Turquie       en
# 4          4  2858299215060733023  user      France       en
# ...      ...                  ...   ...         ...      ...
# 98908  98908 -5324380437900495747  user  Etats-Unis       fr
# 98909  98909 -5607668753771114442  user      France       fr
# 98910  98910   350630276238833248  user    Belgique       en
# 98911  98911  2006580738726207028  user      Italie       it
# 98912  98912 -7621316584087253691  user      Guinée       fr
#
#        socialNbFollowers  socialNbFollows  socialProductsLiked  \
# 0                      3                8                    0
# 1                      3                8                    0
# ...

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98913 entries, 0 to 98912
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   index                98913 non-null  int64
#  1   identifierHash       98913 non-null  int64
#  2   type                 98913 non-null  object
#  3   country              98913 non-null  object
#  4   language             98913 non-null  object
#  5   socialNbFollowers    98913 non-null  int64
#  6   socialNbFollows      98913 non-null  int64
#  7   socialProductsLiked  98913 non-null  int64
#  8   productsListed       98913 non-null  int64
#  9   productsSold         98913 non-null  int64
#  10  productsPassRate     98913 non-null  float64
#  11  productsWished       98913 non-null  int64
#  12  productsBought       98913 non-null  int64
#  13  gender               98913 non-null  object
#  14  civilityGenderId     98913 non-null  int64
# ...

# %%
users['socialProductsLiked'].unique()
# Out:
# array([    0,     4,   370,     1,    27,     2,     8,    12,    13,
#           56,     7,    31,    52,     6,     3,    20,    17,    23,
#          150,     9,     5,    21,    26,    11,    25,    15,    89,
#           39,    28,    24,    71,    64,    14,    33,    19,   167,
#           10,   373,    46,    35,   113,   475,    16,    61,   124,
#         1513,   541,    32,   195,   428,   404,    34,    55,   134,
#           70,   218,   177,    63,  1290,    49,    18,    22,    44,
#           48,   101,    36,    42,    40,    72,    38,   191,    41,
#           30,   410,    97,   145,    60,   413,    29,   123,    45,
#          111,    76,   107,    59,    62,   334,   142,    51,   264,
#          116,    53,   170,   115,   808,   520,    47,   755,   288,
#          146,    37,    67,   599,    43,   274,   184,    95,  1751,
#           66,   106,   179,   253,   839,   297,    73,   396,   133,
# ...

# %%
users_copy=users.copy()

# %%
df_users= users_copy.loc[:,['socialProductsLiked','seniority','productsWished','productsBought']]

# %%
df_users.head()
# Out:
#    socialProductsLiked  seniority  productsWished  productsBought
# 0                    0       3205               0               0
# 1                    0       3205               0               0
# 2                    0       3205               0               0
# 3                    0       3205               0               0
# 4                    0       3205               0               0

# %%
df_users.to_csv('df_users.csv')
